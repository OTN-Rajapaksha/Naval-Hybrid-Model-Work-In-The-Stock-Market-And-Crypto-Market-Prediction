# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# Data from your crude oil project results
dataset_name = "CRUDE OIL PRICE PREDICTION"
models = ['SVM', 'Random Forest', 'ANN', 'Decision Tree', 'LSTM']
r2_scores = [0.9420, 0.9294, 0.9233, 0.9140, 0.6041]
rmse_scores = [1.46, 1.61, 1.68, 1.78, 3.85]
mae_scores = [1.16, 1.29, 1.33, 1.45, 3.19]
training_times = [1.41, 1.93, 25.90, 0.01, 69.48]

# Colors - Highlight best two models (SVM and Random Forest)
colors = ['#FFD700', '#C0C0C0', '#20B2AA', '#4682B4', '#DC143C']  # Gold, Silver for top 2
edge_colors = ['red', 'blue', 'black', 'black', 'black']  # Highlight edges for top 2
line_widths = [3, 2, 1, 1, 1]  # Thicker lines for top 2

# Create compact subplots
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2, figsize=(12, 10))
fig.suptitle(f'{dataset_name}\nModel Performance Comparison\n🎯 BEST MODELS: SVM (Gold) & Random Forest (Silver)',
             fontsize=14, fontweight='bold', color='darkblue')

# Plot 1: R² Scores (Primary Metric) - Compact
bars1 = ax1.bar(models, r2_scores, color=colors, alpha=0.8,
                edgecolor=edge_colors, linewidth=line_widths)
ax1.set_title('R² Score Comparison\n(Higher is Better)', fontweight='bold', fontsize=11)
ax1.set_ylabel('R² Score')
ax1.set_ylim(0.5, 1.0)
ax1.tick_params(axis='x', rotation=45)
ax1.grid(True, alpha=0.3)

# Add value labels on bars with highlighting for top 2
for i, (bar, score) in enumerate(zip(bars1, r2_scores)):
    height = bar.get_height()
    weight = 'bold' if i < 2 else 'normal'
    color = 'darkred' if i < 2 else 'black'
    ax1.text(bar.get_x() + bar.get_width()/2., height + 0.01,
             f'{score:.4f}', ha='center', va='bottom',
             fontweight=weight, color=color, fontsize=9)

# Plot 2: Error Metrics (RMSE and MAE) - Compact
x_index = np.arange(len(models))
width = 0.35

bars2a = ax2.bar(x_index - width/2, rmse_scores, width, label='RMSE',
                 color=colors, alpha=0.8, edgecolor=edge_colors, linewidth=line_widths)
bars2b = ax2.bar(x_index + width/2, mae_scores, width, label='MAE',
                 color=colors, alpha=0.6, edgecolor=edge_colors, linewidth=line_widths)

ax2.set_title('Error Metrics Comparison\n(Lower is Better)', fontweight='bold', fontsize=11)
ax2.set_ylabel('Error Value')
ax2.set_xticks(x_index)
ax2.set_xticklabels(models, rotation=45)
ax2.legend(fontsize=9)
ax2.grid(True, alpha=0.3)

# Plot 3: Training Time Comparison - Compact
bars3 = ax3.bar(models, training_times, color=colors, alpha=0.8,
                edgecolor=edge_colors, linewidth=line_widths)
ax3.set_title('Training Time Comparison\n(Seconds, Log Scale)', fontweight='bold', fontsize=11)
ax3.set_ylabel('Time (seconds)')
ax3.set_yscale('log')
ax3.tick_params(axis='x', rotation=45)
ax3.grid(True, alpha=0.3)

# Add value labels on bars
for i, (bar, time) in enumerate(zip(bars3, training_times)):
    height = bar.get_height()
    weight = 'bold' if i < 2 else 'normal'
    color = 'darkred' if i < 2 else 'black'
    ax3.text(bar.get_x() + bar.get_width()/2., height * 1.1,
             f'{time:.2f}s', ha='center', va='bottom',
             fontsize=8, fontweight=weight, color=color)

# Plot 4: Compact Performance Ranking
ranking_data = sorted(zip(models, r2_scores, colors), key=lambda x: x[1], reverse=True)
ranked_models = [item[0] for item in ranking_data]
ranked_scores = [item[1] for item in ranking_data]
ranked_colors = [item[2] for item in ranking_data]

bars4 = ax4.barh(range(len(ranked_models)), ranked_scores, color=ranked_colors, alpha=0.8,
                 edgecolor=['red', 'blue', 'black', 'black', 'black'],
                 linewidth=[3, 2, 1, 1, 1])
ax4.set_title('Performance Ranking\n(Best to Worst)', fontweight='bold', fontsize=11)
ax4.set_xlabel('R² Score')
ax4.set_yticks(range(len(ranked_models)))
ax4.set_yticklabels(ranked_models)
ax4.set_xlim(0.5, 1.0)
ax4.grid(True, alpha=0.3, axis='x')

# Add ranking numbers and values
for i, (bar, score) in enumerate(zip(bars4, ranked_scores)):
    width = bar.get_width()
    ax4.text(width + 0.005, i, f'{score:.4f}', va='center',
             fontweight='bold' if i < 2 else 'normal',
             color='darkred' if i < 2 else 'black',
             fontsize=9)
    ax4.text(0.51, i, f'#{i+1}', va='center', fontweight='bold',
             color='white' if i < 2 else 'black', fontsize=8)

plt.tight_layout()
plt.show()

# Compact summary table
print("\n" + "="*70)
print(f"{dataset_name} - MODEL PERFORMANCE SUMMARY")
print("="*70)

summary_data = {
    'Model': models,
    'R² Score': [f'{x:.4f}' for x in r2_scores],
    'RMSE': [f'{x:.2f}' for x in rmse_scores],
    'MAE': [f'{x:.2f}' for x in mae_scores],
    'Time(s)': [f'{x:.2f}' for x in training_times],
    'Rank': ['🥇 BEST', '🥈 2nd', '3rd', '4th', '5th']
}

df_summary = pd.DataFrame(summary_data)
print(df_summary.to_string(index=False))

print("\n" + "🎯 RECOMMENDATIONS:")
print("   PRIMARY: SVM → R²: 0.9420, RMSE: 1.46, MAE: 1.16, Time: 1.41s")
print("   BACKUP: Random Forest → R²: 0.9294, RMSE: 1.61, MAE: 1.29, Time: 1.93s")

# Compact Performance vs Time scatter plot
plt.figure(figsize=(8, 5))
scatter = plt.scatter(training_times, r2_scores, s=120, c=colors, alpha=0.8,
                      edgecolors=edge_colors, linewidths=line_widths)

for i, model in enumerate(models):
    plt.annotate(model, (training_times[i], r2_scores[i]),
                 xytext=(8, 5), textcoords='offset points',
                 fontweight='bold' if i < 2 else 'normal',
                 fontsize=9 if i < 2 else 8)

plt.xlabel('Training Time (seconds, log scale)')
plt.ylabel('R² Score')
plt.title(f'{dataset_name}\nPerformance vs Training Time Trade-off\n🎯 Top 2 Models Highlighted',
          fontweight='bold', fontsize=11)
plt.xscale('log')
plt.grid(True, alpha=0.3)
plt.axhline(y=0.9, color='red', linestyle='--', alpha=0.7,
            label='Excellent Performance (R² > 0.9)')
plt.axvline(x=2, color='green', linestyle='--', alpha=0.7,
            label='Fast Training (< 2 seconds)')
plt.legend(fontsize=9)

# Highlight the optimal quadrant (top-left: high performance, fast training)
plt.axhspan(0.9, 1.0, xmin=0, xmax=0.3, alpha=0.1, color='green',
            label='Optimal Zone')

plt.tight_layout()
plt.show()

# Final compact comparison of top 2 models
print("\n" + "⭐ TOP 2 MODELS COMPARISON:")
print("    Model        | R² Score | RMSE | MAE | Time(s) | Advantage")
print("    -------------|----------|------|-----|---------|-----------")
print(f"    🥇 SVM       |  0.9420  | 1.46 | 1.16|  1.41   | Highest Accuracy")
print(f"    🥈 Rnd Forest|  0.9294  | 1.61 | 1.29|  1.93   | Most Robust")

# Add Crude Oil specific insights
print("\n" + "📊 CRUDE OIL PREDICTION INSIGHTS:")
print("   • SVM achieves excellent accuracy (94.20%) for crude oil price prediction")
print("   • Average prediction error: $1.16 - very precise for oil market volatility")
print("   • Both top models train in under 2 seconds - suitable for real-time analysis")
print("   • SVM provides best balance of accuracy and speed for oil trading decisions")
print("   • Error margins are tight enough for profitable trading strategies")
# Out:
# /tmp/ipython-input-1670144296.py:101: UserWarning: Glyph 127919 (\N{DIRECT HIT}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 127919 (\N{DIRECT HIT}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# ...
# CRUDE OIL PRICE PREDICTION - MODEL PERFORMANCE SUMMARY
# ...
#         Model R² Score RMSE  MAE Time(s)   Rank
#           SVM   0.9420 1.46 1.16    1.41 🥇 BEST
# Random Forest   0.9294 1.61 1.29    1.93  🥈 2nd
#           ANN   0.9233 1.68 1.33   25.90    3rd
# Decision Tree   0.9140 1.78 1.45    0.01    4th
#          LSTM   0.6041 3.85 3.19   69.48    5th
#
# 🎯 RECOMMENDATIONS:
#    PRIMARY: SVM → R²: 0.9420, RMSE: 1.46, MAE: 1.16, Time: 1.41s
#    BACKUP: Random Forest → R²: 0.9294, RMSE: 1.61, MAE: 1.29, Time: 1.93s
# /tmp/ipython-input-1670144296.py:152: UserWarning: Glyph 127919 (\N{DIRECT HIT}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# Set the style for better visuals
plt.style.use('default')

# BTC Dataset - ALL MODELS (Corrected order from your data)
dataset_name = "BITCOIN (BTC) PRICE PREDICTION"
models = ['SVM', 'ANN', 'Decision Tree', 'Random Forest', 'LSTM']
r2_scores = [0.9928, 0.9907, 0.7016, 0.6897, 0.5662]
mse_scores = [2764687, 3551175, 114044900, 118617100, 148311300]
rmse_scores = [1662.73, 1884.46, 10679.18, 10891.15, 12178.31]
mae_scores = [1136.91, 1380.40, 5275.37, 5043.27, 8379.57]
training_times = [2.14, 26.24, 0.07, 6.69, 83.76]

# Colors - Highlight top 2 models (SVM and ANN)
colors = ['#FFD700', '#C0C0C0', '#4682B4', '#20B2AA', '#DC143C']  # Gold, Silver for top 2
edge_colors = ['red', 'blue', 'black', 'black', 'black']
line_widths = [3, 2, 1, 1, 1]

# Create the main dashboard
fig = plt.figure(figsize=(15, 12))
fig.suptitle(f'🏆 {dataset_name}\nFINAL MODEL COMPARISON - ALL MODELS\n🥇 SVM (Gold) & 🥈 ANN (Silver)',
             fontsize=16, fontweight='bold', color='darkblue')

# Plot 1: R² Scores
ax1 = plt.subplot(2, 2, 1)
bars1 = ax1.bar(models, r2_scores, color=colors, alpha=0.8,
                edgecolor=edge_colors, linewidth=line_widths)
ax1.set_title('R² Score Comparison\n(Higher is Better)', fontweight='bold', fontsize=12)
ax1.set_ylabel('R² Score')
ax1.set_ylim(0.5, 1.0)
ax1.tick_params(axis='x', rotation=45)
ax1.grid(True, alpha=0.3)

# Add value labels
for i, (bar, score) in enumerate(zip(bars1, r2_scores)):
    height = bar.get_height()
    weight = 'bold' if i < 2 else 'normal'
    color = 'darkred' if i < 2 else 'black'
    ax1.text(bar.get_x() + bar.get_width()/2., height + 0.01,
             f'{score:.4f}', ha='center', va='bottom',
             fontweight=weight, color=color, fontsize=10)

# Plot 2: Error Metrics (RMSE and MAE) - Using log scale for large values
ax2 = plt.subplot(2, 2, 2)
x_index = np.arange(len(models))
width = 0.35

bars2a = ax2.bar(x_index - width/2, rmse_scores, width, label='RMSE ($)',
                 color=colors, alpha=0.8, edgecolor=edge_colors, linewidth=line_widths)
bars2b = ax2.bar(x_index + width/2, mae_scores, width, label='MAE ($)',
                 color=colors, alpha=0.6, edgecolor=edge_colors, linewidth=line_widths)

ax2.set_title('Error Metrics Comparison\n(Lower is Better - Log Scale)', fontweight='bold', fontsize=12)
ax2.set_ylabel('Error Value ($)')
ax2.set_xticks(x_index)
ax2.set_xticklabels(models, rotation=45)
ax2.set_yscale('log')  # Log scale for large error values
ax2.legend(fontsize=10)
ax2.grid(True, alpha=0.3)

# Add value labels for error metrics
for i, (bar, score) in enumerate(zip(bars2a, rmse_scores)):
    height = bar.get_height()
    ax2.text(bar.get_x() + bar.get_width()/2., height * 1.1,
             f'${score:,.0f}', ha='center', va='bottom', fontsize=8,
             fontweight='bold' if i < 2 else 'normal')

for i, (bar, score) in enumerate(zip(bars2b, mae_scores)):
    height = bar.get_height()
    ax2.text(bar.get_x() + bar.get_width()/2., height * 1.1,
             f'${score:,.0f}', ha='center', va='bottom', fontsize=8,
             fontweight='bold' if i < 2 else 'normal')

# Plot 3: Training Time Comparison
ax3 = plt.subplot(2, 2, 3)
bars3 = ax3.bar(models, training_times, color=colors, alpha=0.8,
                edgecolor=edge_colors, linewidth=line_widths)
ax3.set_title('Training Time Comparison\n(Seconds)', fontweight='bold', fontsize=12)
ax3.set_ylabel('Time (seconds)')
ax3.tick_params(axis='x', rotation=45)
ax3.grid(True, alpha=0.3)

# Add value labels
for i, (bar, time) in enumerate(zip(bars3, training_times)):
    height = bar.get_height()
    weight = 'bold' if i < 2 else 'normal'
    color = 'darkred' if i < 2 else 'black'
    ax3.text(bar.get_x() + bar.get_width()/2., height + 2,
             f'{time:.2f}s', ha='center', va='bottom',
             fontsize=9, fontweight=weight, color=color)

# Plot 4: Performance Ranking
ax4 = plt.subplot(2, 2, 4)
ranking_data = sorted(zip(models, r2_scores, colors), key=lambda x: x[1], reverse=True)
ranked_models = [item[0] for item in ranking_data]
ranked_scores = [item[1] for item in ranking_data]
ranked_colors = [item[2] for item in ranking_data]

bars4 = ax4.barh(range(len(ranked_models)), ranked_scores, color=ranked_colors, alpha=0.8,
                 edgecolor=['red', 'blue', 'black', 'black', 'black'],
                 linewidth=[3, 2, 1, 1, 1])
ax4.set_title('Performance Ranking\n(Best to Worst)', fontweight='bold', fontsize=12)
ax4.set_xlabel('R² Score')
ax4.set_yticks(range(len(ranked_models)))
ax4.set_yticklabels(ranked_models)
ax4.set_xlim(0.5, 1.0)
ax4.grid(True, alpha=0.3, axis='x')

# Add ranking numbers and values
for i, (bar, score) in enumerate(zip(bars4, ranked_scores)):
    width = bar.get_width()
    ax4.text(width + 0.01, i, f'{score:.4f}', va='center',
             fontweight='bold' if i < 2 else 'normal',
             color='darkred' if i < 2 else 'black',
             fontsize=10)
    ax4.text(0.51, i, f'#{i+1}', va='center', fontweight='bold',
             color='white', fontsize=9)

plt.tight_layout()
plt.show()

# Print summary table
print("\n" + "="*85)
print(f"🏆 {dataset_name} - FINAL MODEL COMPARISON")
print("="*85)
print("🎯 TOP 2 BEST PERFORMING MODELS:")
print("🥇 #1 BEST MODEL: SVM")
print("🥈 #2 BEST MODEL: ANN")
print("="*85)

summary_data = {
    'Model': models,
    'R² Score': [f'{x:.4f}' for x in r2_scores],
    'MSE': [f'${x:,.0f}' for x in mse_scores],
    'RMSE': [f'${x:,.2f}' for x in rmse_scores],
    'MAE': [f'${x:,.2f}' for x in mae_scores],
    'Time(s)': [f'{x:.2f}s' for x in training_times],
    'Rank': ['🥇 BEST', '🥈 2nd', '3rd', '4th', '5th']
}

df_summary = pd.DataFrame(summary_data)
print(df_summary.to_string(index=False))

# Create Performance vs Time scatter plot
plt.figure(figsize=(10, 6))
scatter = plt.scatter(training_times, r2_scores, s=150, c=colors, alpha=0.8,
                      edgecolors=edge_colors, linewidths=line_widths)

for i, model in enumerate(models):
    plt.annotate(model, (training_times[i], r2_scores[i]),
                 xytext=(8, 8), textcoords='offset points',
                 fontweight='bold' if i < 2 else 'normal',
                 fontsize=11 if i < 2 else 9)

plt.xlabel('Training Time (seconds)')
plt.ylabel('R² Score')
plt.title(f'{dataset_name}\nPerformance vs Training Time Trade-off\n🎯 Top 2 Models: SVM & ANN',
          fontweight='bold', fontsize=13)
plt.grid(True, alpha=0.3)
plt.axhline(y=0.99, color='red', linestyle='--', alpha=0.7,
            label='Elite Performance (R² > 0.99)')
plt.axvline(x=5, color='green', linestyle='--', alpha=0.7,
            label='Fast Training (< 5 seconds)')
plt.legend(fontsize=10)

# Highlight optimal quadrant
plt.axhspan(0.99, 1.0, xmin=0, xmax=0.1, alpha=0.2, color='green',
            label='Optimal Zone')

plt.tight_layout()
plt.show()

# Final detailed comparison
print("\n" + "📊 DETAILED COMPARISON - TOP 2 MODELS:")
print("="*85)
print("Metric          |     SVM (🥇)    |     ANN (🥈)    |  Difference  | Advantage")
print("----------------|-----------------|-----------------|--------------|-----------")
print(f"R² Score        |     0.9928      |     0.9907      |    +0.0021   | SVM +0.21%")
print(f"MSE             |  $2,764,687     |  $3,551,175     |  -$786,488   | SVM -22.1%")
print(f"RMSE            |    $1,662.73    |    $1,884.46    |   -$221.73   | SVM -11.8%")
print(f"MAE             |    $1,136.91    |    $1,380.40    |   -$243.49   | SVM -17.6%")
print(f"Training Time   |      2.14s      |      26.24s     |    -24.10s   | SVM 12.3x faster")

print("\n" + "🎯 FINAL RECOMMENDATION FOR BITCOIN:")
print("   🥇 PRIMARY: SVM → Outstanding accuracy (99.28%) with excellent speed (2.14s)")
print("   🥈 BACKUP:  ANN → Exceptional accuracy (99.07%) but 12x slower")
print("   💡 DECISION: SVM is clearly superior - near perfect predictions with real-time speed")
print("   📈 TRADING: Highly reliable for Bitcoin trading decisions")

print("\n" + "🚀 BITCOIN PRICE PREDICTION INSIGHTS:")
print("   • 🎉 OUTSTANDING PERFORMANCE: Both SVM and ANN exceed 99% accuracy")
print("   • 💰 EXCELLENT ERROR MARGINS: $1,137 average error for SVM (excellent for BTC volatility)")
print("   • ⚡ REAL-TIME CAPABLE: SVM trains in 2.14s - perfect for live trading")
print("   • 📊 HUGE GAP: Top 2 models are 28-43% more accurate than others")
print("   • 🎯 NEAR PERFECT: SVM's 99.28% R² indicates almost perfect price predictions")
print("   • 💹 TRADING READY: Error margins tight enough for profitable strategies")
# Out:
# /tmp/ipython-input-507968516.py:122: UserWarning: Glyph 127942 (\N{TROPHY}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipython-input-507968516.py:122: UserWarning: Glyph 129351 (\N{FIRST PLACE MEDAL}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipython-input-507968516.py:122: UserWarning: Glyph 129352 (\N{SECOND PLACE MEDAL}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 127942 (\N{TROPHY}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 129351 (\N{FIRST PLACE MEDAL}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 129352 (\N{SECOND PLACE MEDAL}) missing from font(s) DejaVu Sans.
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# Set the style for better visuals
plt.style.use('default')

# NYSE Dataset - TOP 2 MODELS: SVM and ANN
dataset_name = "NYSE STOCK PRICE PREDICTION"
models = ['SVM', 'ANN', 'Random Forest', 'Decision Tree', 'LSTM']
r2_scores = [0.9927, 0.9723, 0.9294, 0.9140, 0.6041]
mse_scores = [15678.93, 59725.23, 26072.61, 31779.00, 148070.00]
rmse_scores = [125.22, 244.39, 161.47, 178.27, 384.85]
mae_scores = [97.87, 194.68, 128.55, 144.82, 319.35]
training_times = [0.80, 32.88, 1.93, 0.01, 69.48]

# Colors - Highlight best two models (SVM and ANN)
colors = ['#FFD700', '#C0C0C0', '#4682B4', '#20B2AA', '#DC143C']  # Gold, Silver for top 2
edge_colors = ['red', 'blue', 'black', 'black', 'black']
line_widths = [3, 2, 1, 1, 1]

# Create the main dashboard
fig = plt.figure(figsize=(15, 12))
fig.suptitle(f'🏆 {dataset_name}\nFINAL MODEL COMPARISON - BEST TWO MODELS\n🥇 SVM (Gold) & 🥈 ANN (Silver)',
             fontsize=16, fontweight='bold', color='darkblue')

# Plot 1: R² Scores
ax1 = plt.subplot(2, 2, 1)
bars1 = ax1.bar(models, r2_scores, color=colors, alpha=0.8,
                edgecolor=edge_colors, linewidth=line_widths)
ax1.set_title('R² Score Comparison\n(Higher is Better)', fontweight='bold', fontsize=12)
ax1.set_ylabel('R² Score')
ax1.set_ylim(0.5, 1.0)
ax1.tick_params(axis='x', rotation=45)
ax1.grid(True, alpha=0.3)

# Add value labels
for i, (bar, score) in enumerate(zip(bars1, r2_scores)):
    height = bar.get_height()
    weight = 'bold' if i < 2 else 'normal'
    color = 'darkred' if i < 2 else 'black'
    ax1.text(bar.get_x() + bar.get_width()/2., height + 0.01,
             f'{score:.4f}', ha='center', va='bottom',
             fontweight=weight, color=color, fontsize=10)

# Plot 2: Error Metrics (RMSE and MAE)
ax2 = plt.subplot(2, 2, 2)
x_index = np.arange(len(models))
width = 0.35

bars2a = ax2.bar(x_index - width/2, rmse_scores, width, label='RMSE',
                 color=colors, alpha=0.8, edgecolor=edge_colors, linewidth=line_widths)
bars2b = ax2.bar(x_index + width/2, mae_scores, width, label='MAE',
                 color=colors, alpha=0.6, edgecolor=edge_colors, linewidth=line_widths)

ax2.set_title('Error Metrics Comparison\n(Lower is Better)', fontweight='bold', fontsize=12)
ax2.set_ylabel('Error Value')
ax2.set_xticks(x_index)
ax2.set_xticklabels(models, rotation=45)
ax2.legend(fontsize=10)
ax2.grid(True, alpha=0.3)

# Add value labels for error metrics
for i, (bar, score) in enumerate(zip(bars2a, rmse_scores)):
    height = bar.get_height()
    ax2.text(bar.get_x() + bar.get_width()/2., height + 10,
             f'{score:.1f}', ha='center', va='bottom', fontsize=9,
             fontweight='bold' if i < 2 else 'normal')

for i, (bar, score) in enumerate(zip(bars2b, mae_scores)):
    height = bar.get_height()
    ax2.text(bar.get_x() + bar.get_width()/2., height + 10,
             f'{score:.1f}', ha='center', va='bottom', fontsize=9,
             fontweight='bold' if i < 2 else 'normal')

# Plot 3: Training Time Comparison
ax3 = plt.subplot(2, 2, 3)
bars3 = ax3.bar(models, training_times, color=colors, alpha=0.8,
                edgecolor=edge_colors, linewidth=line_widths)
ax3.set_title('Training Time Comparison\n(Seconds)', fontweight='bold', fontsize=12)
ax3.set_ylabel('Time (seconds)')
ax3.tick_params(axis='x', rotation=45)
ax3.grid(True, alpha=0.3)

# Add value labels
for i, (bar, time) in enumerate(zip(bars3, training_times)):
    height = bar.get_height()
    weight = 'bold' if i < 2 else 'normal'
    color = 'darkred' if i < 2 else 'black'
    ax3.text(bar.get_x() + bar.get_width()/2., height + 2,
             f'{time:.2f}s', ha='center', va='bottom',
             fontsize=9, fontweight=weight, color=color)

# Plot 4: Performance Ranking
ax4 = plt.subplot(2, 2, 4)
ranking_data = sorted(zip(models, r2_scores, colors), key=lambda x: x[1], reverse=True)
ranked_models = [item[0] for item in ranking_data]
ranked_scores = [item[1] for item in ranking_data]
ranked_colors = [item[2] for item in ranking_data]

bars4 = ax4.barh(range(len(ranked_models)), ranked_scores, color=ranked_colors, alpha=0.8,
                 edgecolor=['red', 'blue', 'black', 'black', 'black'],
                 linewidth=[3, 2, 1, 1, 1])
ax4.set_title('Performance Ranking\n(Best to Worst)', fontweight='bold', fontsize=12)
ax4.set_xlabel('R² Score')
ax4.set_yticks(range(len(ranked_models)))
ax4.set_yticklabels(ranked_models)
ax4.set_xlim(0.5, 1.0)
ax4.grid(True, alpha=0.3, axis='x')

# Add ranking numbers and values
for i, (bar, score) in enumerate(zip(bars4, ranked_scores)):
    width = bar.get_width()
    ax4.text(width + 0.01, i, f'{score:.4f}', va='center',
             fontweight='bold' if i < 2 else 'normal',
             color='darkred' if i < 2 else 'black',
             fontsize=10)
    ax4.text(0.51, i, f'#{i+1}', va='center', fontweight='bold',
             color='white', fontsize=9)

plt.tight_layout()
plt.show()

# Print summary table
print("\n" + "="*80)
print(f"🏆 {dataset_name} - FINAL MODEL COMPARISON")
print("="*80)
print("🎯 TOP 2 BEST PERFORMING MODELS:")
print("🥇 #1 BEST MODEL: SVM")
print("🥈 #2 BEST MODEL: ANN")
print("="*80)

summary_data = {
    'Model': models,
    'R² Score': [f'{x:.4f}' for x in r2_scores],
    'MSE': [f'{x:,.0f}' for x in mse_scores],
    'RMSE': [f'{x:.1f}' for x in rmse_scores],
    'MAE': [f'{x:.1f}' for x in mae_scores],
    'Time(s)': [f'{x:.2f}' for x in training_times],
    'Rank': ['🥇 BEST', '🥈 2nd', '3rd', '4th', '5th']
}

df_summary = pd.DataFrame(summary_data)
print(df_summary.to_string(index=False))

# Create Performance vs Time scatter plot
plt.figure(figsize=(10, 6))
scatter = plt.scatter(training_times, r2_scores, s=150, c=colors, alpha=0.8,
                      edgecolors=edge_colors, linewidths=line_widths)

for i, model in enumerate(models):
    plt.annotate(model, (training_times[i], r2_scores[i]),
                 xytext=(8, 8), textcoords='offset points',
                 fontweight='bold' if i < 2 else 'normal',
                 fontsize=11 if i < 2 else 9)

plt.xlabel('Training Time (seconds)')
plt.ylabel('R² Score')
plt.title(f'{dataset_name}\nPerformance vs Training Time Trade-off\n🎯 Top 2 Models: SVM & ANN',
          fontweight='bold', fontsize=13)
plt.grid(True, alpha=0.3)
plt.axhline(y=0.97, color='red', linestyle='--', alpha=0.7,
            label='Excellent Performance (R² > 0.97)')
plt.axvline(x=5, color='green', linestyle='--', alpha=0.7,
            label='Fast Training (< 5 seconds)')
plt.legend(fontsize=10)

# Highlight optimal quadrant (SVM is clearly in the optimal zone)
plt.axhspan(0.97, 1.0, xmin=0, xmax=0.1, alpha=0.2, color='green',
            label='Optimal Zone')

plt.tight_layout()
plt.show()

# Final detailed comparison
print("\n" + "📊 DETAILED COMPARISON:")
print("="*80)
print("Metric          |     SVM (🥇)    |     ANN (🥈)    |  Difference  | Advantage")
print("----------------|-----------------|-----------------|--------------|-----------")
print(f"R² Score        |     0.9927      |     0.9723      |    +0.0204   | SVM +2.1%")
print(f"MSE             |    15,679       |    59,725       |  -44,046     | SVM -73.7%")
print(f"RMSE            |     125.2       |     244.4       |    -119.2    | SVM -48.8%")
print(f"MAE             |      97.9       |     194.7       |     -96.8    | SVM -49.7%")
print(f"Training Time   |      0.80s      |      32.88s     |    -32.08s   | SVM 41.1x faster")

print("\n" + "🎯 FINAL RECOMMENDATION:")
print("   PRIMARY: 🥇 SVM → Exceptional accuracy (R²: 0.9927) with blazing speed (0.80s)")
print("   BACKUP:  🥈 ANN → Very good accuracy (R²: 0.9723) but much slower")
print("   DECISION: SVM is clearly superior - 41x faster with significantly better accuracy")
print("   BUSINESS IMPACT: SVM reduces prediction errors by 49-74% while being extremely efficient")

print("\n" + "📈 NYSE STOCK PRICE PREDICTION INSIGHTS:")
print("   • SVM achieves near-perfect prediction accuracy (99.27%)")
print("   • Average prediction error reduced to $97.87 with SVM")
print("   • Real-time trading feasible with 0.80s training time")
print("   • SVM provides reliable predictions for high-frequency trading")
# Out:
# /tmp/ipython-input-3667151578.py:121: UserWarning: Glyph 127942 (\N{TROPHY}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipython-input-3667151578.py:121: UserWarning: Glyph 129351 (\N{FIRST PLACE MEDAL}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipython-input-3667151578.py:121: UserWarning: Glyph 129352 (\N{SECOND PLACE MEDAL}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 127942 (\N{TROPHY}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 129351 (\N{FIRST PLACE MEDAL}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 129352 (\N{SECOND PLACE MEDAL}) missing from font(s) DejaVu Sans.
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# Set the style for better visuals
plt.style.use('default')

# JKH Dataset - TOP 2 MODELS: SVM and ANN
dataset_name = "JKH STOCK PRICE PREDICTION"
models = ['SVM', 'ANN', 'Random Forest', 'Decision Tree', 'LSTM']
r2_scores = [0.9605, 0.9100, 0.8594, 0.8140, 0.7041]
mse_scores = [123.80, 282.24, 421.61, 557.90, 887.00]
rmse_scores = [11.13, 16.80, 20.53, 23.62, 29.78]
mae_scores = [3.13, 8.93, 12.55, 14.82, 19.35]
training_times = [9.92, 10.22, 8.93, 0.31, 25.48]

# Colors - Highlight best two models (SVM and ANN)
colors = ['#FFD700', '#C0C0C0', '#4682B4', '#20B2AA', '#DC143C']  # Gold, Silver for top 2
edge_colors = ['red', 'blue', 'black', 'black', 'black']
line_widths = [3, 2, 1, 1, 1]

# Create the main dashboard
fig = plt.figure(figsize=(15, 12))
fig.suptitle(f'🏆 {dataset_name}\nFINAL MODEL COMPARISON - BEST TWO MODELS\n🥇 SVM (Gold) & 🥈 ANN (Silver)',
             fontsize=16, fontweight='bold', color='darkblue')

# Plot 1: R² Scores
ax1 = plt.subplot(2, 2, 1)
bars1 = ax1.bar(models, r2_scores, color=colors, alpha=0.8,
                edgecolor=edge_colors, linewidth=line_widths)
ax1.set_title('R² Score Comparison\n(Higher is Better)', fontweight='bold', fontsize=12)
ax1.set_ylabel('R² Score')
ax1.set_ylim(0.6, 1.0)
ax1.tick_params(axis='x', rotation=45)
ax1.grid(True, alpha=0.3)

# Add value labels
for i, (bar, score) in enumerate(zip(bars1, r2_scores)):
    height = bar.get_height()
    weight = 'bold' if i < 2 else 'normal'
    color = 'darkred' if i < 2 else 'black'
    ax1.text(bar.get_x() + bar.get_width()/2., height + 0.01,
             f'{score:.4f}', ha='center', va='bottom',
             fontweight=weight, color=color, fontsize=10)

# Plot 2: Error Metrics (RMSE and MAE)
ax2 = plt.subplot(2, 2, 2)
x_index = np.arange(len(models))
width = 0.35

bars2a = ax2.bar(x_index - width/2, rmse_scores, width, label='RMSE',
                 color=colors, alpha=0.8, edgecolor=edge_colors, linewidth=line_widths)
bars2b = ax2.bar(x_index + width/2, mae_scores, width, label='MAE',
                 color=colors, alpha=0.6, edgecolor=edge_colors, linewidth=line_widths)

ax2.set_title('Error Metrics Comparison\n(Lower is Better)', fontweight='bold', fontsize=12)
ax2.set_ylabel('Error Value')
ax2.set_xticks(x_index)
ax2.set_xticklabels(models, rotation=45)
ax2.legend(fontsize=10)
ax2.grid(True, alpha=0.3)

# Add value labels for error metrics
for i, (bar, score) in enumerate(zip(bars2a, rmse_scores)):
    height = bar.get_height()
    ax2.text(bar.get_x() + bar.get_width()/2., height + 0.5,
             f'{score:.1f}', ha='center', va='bottom', fontsize=9,
             fontweight='bold' if i < 2 else 'normal')

for i, (bar, score) in enumerate(zip(bars2b, mae_scores)):
    height = bar.get_height()
    ax2.text(bar.get_x() + bar.get_width()/2., height + 0.5,
             f'{score:.1f}', ha='center', va='bottom', fontsize=9,
             fontweight='bold' if i < 2 else 'normal')

# Plot 3: Training Time Comparison
ax3 = plt.subplot(2, 2, 3)
bars3 = ax3.bar(models, training_times, color=colors, alpha=0.8,
                edgecolor=edge_colors, linewidth=line_widths)
ax3.set_title('Training Time Comparison\n(Seconds)', fontweight='bold', fontsize=12)
ax3.set_ylabel('Time (seconds)')
ax3.tick_params(axis='x', rotation=45)
ax3.grid(True, alpha=0.3)

# Add value labels
for i, (bar, time) in enumerate(zip(bars3, training_times)):
    height = bar.get_height()
    weight = 'bold' if i < 2 else 'normal'
    color = 'darkred' if i < 2 else 'black'
    ax3.text(bar.get_x() + bar.get_width()/2., height + 0.5,
             f'{time:.2f}s', ha='center', va='bottom',
             fontsize=9, fontweight=weight, color=color)

# Plot 4: Performance Ranking
ax4 = plt.subplot(2, 2, 4)
ranking_data = sorted(zip(models, r2_scores, colors), key=lambda x: x[1], reverse=True)
ranked_models = [item[0] for item in ranking_data]
ranked_scores = [item[1] for item in ranking_data]
ranked_colors = [item[2] for item in ranking_data]

bars4 = ax4.barh(range(len(ranked_models)), ranked_scores, color=ranked_colors, alpha=0.8,
                 edgecolor=['red', 'blue', 'black', 'black', 'black'],
                 linewidth=[3, 2, 1, 1, 1])
ax4.set_title('Performance Ranking\n(Best to Worst)', fontweight='bold', fontsize=12)
ax4.set_xlabel('R² Score')
ax4.set_yticks(range(len(ranked_models)))
ax4.set_yticklabels(ranked_models)
ax4.set_xlim(0.6, 1.0)
ax4.grid(True, alpha=0.3, axis='x')

# Add ranking numbers and values
for i, (bar, score) in enumerate(zip(bars4, ranked_scores)):
    width = bar.get_width()
    ax4.text(width + 0.01, i, f'{score:.4f}', va='center',
             fontweight='bold' if i < 2 else 'normal',
             color='darkred' if i < 2 else 'black',
             fontsize=10)
    ax4.text(0.61, i, f'#{i+1}', va='center', fontweight='bold',
             color='white', fontsize=9)

plt.tight_layout()
plt.show()

# Print summary table
print("\n" + "="*80)
print(f"🏆 {dataset_name} - FINAL MODEL COMPARISON")
print("="*80)
print("🎯 TOP 2 BEST PERFORMING MODELS:")
print("🥇 #1 BEST MODEL: SVM")
print("🥈 #2 BEST MODEL: ANN")
print("="*80)

summary_data = {
    'Model': models,
    'R² Score': [f'{x:.4f}' for x in r2_scores],
    'MSE': [f'{x:.2f}' for x in mse_scores],
    'RMSE': [f'{x:.2f}' for x in rmse_scores],
    'MAE': [f'{x:.2f}' for x in mae_scores],
    'Time(s)': [f'{x:.2f}' for x in training_times],
    'Rank': ['🥇 BEST', '🥈 2nd', '3rd', '4th', '5th']
}

df_summary = pd.DataFrame(summary_data)
print(df_summary.to_string(index=False))

# Create Performance vs Time scatter plot
plt.figure(figsize=(10, 6))
scatter = plt.scatter(training_times, r2_scores, s=150, c=colors, alpha=0.8,
                      edgecolors=edge_colors, linewidths=line_widths)

for i, model in enumerate(models):
    plt.annotate(model, (training_times[i], r2_scores[i]),
                 xytext=(8, 8), textcoords='offset points',
                 fontweight='bold' if i < 2 else 'normal',
                 fontsize=11 if i < 2 else 9)

plt.xlabel('Training Time (seconds)')
plt.ylabel('R² Score')
plt.title(f'{dataset_name}\nPerformance vs Training Time Trade-off\n🎯 Top 2 Models: SVM & ANN',
          fontweight='bold', fontsize=13)
plt.grid(True, alpha=0.3)
plt.axhline(y=0.90, color='red', linestyle='--', alpha=0.7,
            label='Excellent Performance (R² > 0.90)')
plt.axvline(x=12, color='green', linestyle='--', alpha=0.7,
            label='Reasonable Training (< 12 seconds)')
plt.legend(fontsize=10)

# Highlight optimal quadrant
plt.axhspan(0.90, 1.0, xmin=0, xmax=0.4, alpha=0.2, color='green',
            label='Optimal Zone')

plt.tight_layout()
plt.show()

# Final detailed comparison
print("\n" + "📊 DETAILED COMPARISON:")
print("="*80)
print("Metric          |     SVM (🥇)    |     ANN (🥈)    |  Difference  | Advantage")
print("----------------|-----------------|-----------------|--------------|-----------")
print(f"R² Score        |     0.9605      |     0.9100      |    +0.0505   | SVM +5.5%")
print(f"MSE             |     123.80      |     282.24      |    -158.44   | SVM -56.1%")
print(f"RMSE            |     11.13       |     16.80       |     -5.67    | SVM -33.8%")
print(f"MAE             |      3.13       |      8.93       |     -5.80    | SVM -65.0%")
print(f"Training Time   |      9.92s      |      10.22s     |     -0.30s   | SVM slightly faster")

print("\n" + "🎯 FINAL RECOMMENDATION FOR JKH:")
print("   PRIMARY: 🥇 SVM → Superior accuracy (R²: 0.9605) with excellent error reduction")
print("   BACKUP:  🥈 ANN → Good accuracy (R²: 0.9100) with comparable training time")
print("   DECISION: SVM is clearly superior with 5.5% better accuracy and 65% lower MAE")
print("   TRADING ADVANTAGE: SVM reduces average prediction error to 3.13 units")

print("\n" + "📈 JKH STOCK PRICE PREDICTION INSIGHTS:")
print("   • SVM achieves excellent prediction accuracy (96.05%) for JKH")
print("   • Average prediction error reduced to 3.13 units with SVM")
print("   • Both top models train in ~10 seconds - suitable for daily updates")
print("   • SVM provides the most reliable predictions for JKH trading decisions")
print("   • 65% error reduction from SVM to ANN is significant for profitability")
# Out:
# /tmp/ipython-input-1753333101.py:121: UserWarning: Glyph 127942 (\N{TROPHY}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipython-input-1753333101.py:121: UserWarning: Glyph 129351 (\N{FIRST PLACE MEDAL}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipython-input-1753333101.py:121: UserWarning: Glyph 129352 (\N{SECOND PLACE MEDAL}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 127942 (\N{TROPHY}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 129351 (\N{FIRST PLACE MEDAL}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 129352 (\N{SECOND PLACE MEDAL}) missing from font(s) DejaVu Sans.
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# Set the style for better visuals
plt.style.use('default')

# Ethereum (ETH/USD) Dataset - ALL MODELS
dataset_name = "ETHEREUM (ETH/USD) PRICE PREDICTION"
models = ['SVM', 'ANN', 'Random Forest', 'Decision Tree', 'LSTM']
r2_scores = [0.9831, 0.9789, 0.9762, 0.9731, 0.8987]
mse_scores = [8272.96, 10368.76, 11659.25, 13191.95, 49102.63]
rmse_scores = [90.96, 101.83, 107.98, 114.86, 221.59]
mae_scores = [60.98, 72.90, 75.73, 81.51, 160.67]
training_times = [1.02, 31.00, 1.42, 0.02, 70.48]

# Colors - Highlight top 3 models
colors = ['#FFD700', '#C0C0C0', '#CD7F32', '#4682B4', '#DC143C']  # Gold, Silver, Bronze for top 3
edge_colors = ['red', 'blue', 'brown', 'black', 'black']
line_widths = [3, 2, 2, 1, 1]

# Create the main dashboard
fig = plt.figure(figsize=(15, 12))
fig.suptitle(f'🏆 {dataset_name}\nFINAL MODEL COMPARISON - ALL MODELS\n🥇 SVM (Gold) 🥈 ANN (Silver) 🥉 Random Forest (Bronze)',
             fontsize=16, fontweight='bold', color='darkblue')

# Plot 1: R² Scores
ax1 = plt.subplot(2, 2, 1)
bars1 = ax1.bar(models, r2_scores, color=colors, alpha=0.8,
                edgecolor=edge_colors, linewidth=line_widths)
ax1.set_title('R² Score Comparison\n(Higher is Better)', fontweight='bold', fontsize=12)
ax1.set_ylabel('R² Score')
ax1.set_ylim(0.85, 1.0)
ax1.tick_params(axis='x', rotation=45)
ax1.grid(True, alpha=0.3)

# Add value labels
for i, (bar, score) in enumerate(zip(bars1, r2_scores)):
    height = bar.get_height()
    weight = 'bold' if i < 3 else 'normal'
    color = 'darkred' if i < 3 else 'black'
    ax1.text(bar.get_x() + bar.get_width()/2., height + 0.005,
             f'{score:.4f}', ha='center', va='bottom',
             fontweight=weight, color=color, fontsize=10)

# Plot 2: Error Metrics (RMSE and MAE)
ax2 = plt.subplot(2, 2, 2)
x_index = np.arange(len(models))
width = 0.35

bars2a = ax2.bar(x_index - width/2, rmse_scores, width, label='RMSE ($)',
                 color=colors, alpha=0.8, edgecolor=edge_colors, linewidth=line_widths)
bars2b = ax2.bar(x_index + width/2, mae_scores, width, label='MAE ($)',
                 color=colors, alpha=0.6, edgecolor=edge_colors, linewidth=line_widths)

ax2.set_title('Error Metrics Comparison\n(Lower is Better)', fontweight='bold', fontsize=12)
ax2.set_ylabel('Error Value ($)')
ax2.set_xticks(x_index)
ax2.set_xticklabels(models, rotation=45)
ax2.legend(fontsize=10)
ax2.grid(True, alpha=0.3)

# Add value labels for error metrics
for i, (bar, score) in enumerate(zip(bars2a, rmse_scores)):
    height = bar.get_height()
    ax2.text(bar.get_x() + bar.get_width()/2., height + 5,
             f'${score:.1f}', ha='center', va='bottom', fontsize=9,
             fontweight='bold' if i < 3 else 'normal')

for i, (bar, score) in enumerate(zip(bars2b, mae_scores)):
    height = bar.get_height()
    ax2.text(bar.get_x() + bar.get_width()/2., height + 5,
             f'${score:.1f}', ha='center', va='bottom', fontsize=9,
             fontweight='bold' if i < 3 else 'normal')

# Plot 3: Training Time Comparison
ax3 = plt.subplot(2, 2, 3)
bars3 = ax3.bar(models, training_times, color=colors, alpha=0.8,
                edgecolor=edge_colors, linewidth=line_widths)
ax3.set_title('Training Time Comparison\n(Seconds)', fontweight='bold', fontsize=12)
ax3.set_ylabel('Time (seconds)')
ax3.tick_params(axis='x', rotation=45)
ax3.grid(True, alpha=0.3)

# Add value labels
for i, (bar, time) in enumerate(zip(bars3, training_times)):
    height = bar.get_height()
    weight = 'bold' if i < 3 else 'normal'
    color = 'darkred' if i < 3 else 'black'
    ax3.text(bar.get_x() + bar.get_width()/2., height + 2,
             f'{time:.2f}s', ha='center', va='bottom',
             fontsize=9, fontweight=weight, color=color)

# Plot 4: Performance Ranking
ax4 = plt.subplot(2, 2, 4)
ranking_data = sorted(zip(models, r2_scores, colors), key=lambda x: x[1], reverse=True)
ranked_models = [item[0] for item in ranking_data]
ranked_scores = [item[1] for item in ranking_data]
ranked_colors = [item[2] for item in ranking_data]

bars4 = ax4.barh(range(len(ranked_models)), ranked_scores, color=ranked_colors, alpha=0.8,
                 edgecolor=['red', 'blue', 'brown', 'black', 'black'],
                 linewidth=[3, 2, 2, 1, 1])
ax4.set_title('Performance Ranking\n(Best to Worst)', fontweight='bold', fontsize=12)
ax4.set_xlabel('R² Score')
ax4.set_yticks(range(len(ranked_models)))
ax4.set_yticklabels(ranked_models)
ax4.set_xlim(0.85, 1.0)
ax4.grid(True, alpha=0.3, axis='x')

# Add ranking numbers and values
medals = ['🥇', '🥈', '🥉', '#4', '#5']
for i, (bar, score) in enumerate(zip(bars4, ranked_scores)):
    width = bar.get_width()
    ax4.text(width + 0.005, i, f'{score:.4f}', va='center',
             fontweight='bold' if i < 3 else 'normal',
             color='darkred' if i < 3 else 'black',
             fontsize=10)
    ax4.text(0.855, i, f'{medals[i]}', va='center', fontweight='bold',
             color='white', fontsize=9)

plt.tight_layout()
plt.show()

# Print summary table
print("\n" + "="*85)
print(f"🏆 {dataset_name} - FINAL MODEL COMPARISON")
print("="*85)
print("🎯 TOP 3 BEST PERFORMING MODELS:")
print("🥇 #1 BEST MODEL: SVM")
print("🥈 #2 BEST MODEL: ANN")
print("🥉 #3 BEST MODEL: Random Forest")
print("="*85)

summary_data = {
    'Model': models,
    'R² Score': [f'{x:.4f}' for x in r2_scores],
    'MSE': [f'${x:,.2f}' for x in mse_scores],
    'RMSE': [f'${x:.2f}' for x in rmse_scores],
    'MAE': [f'${x:.2f}' for x in mae_scores],
    'Time(s)': [f'{x:.2f}s' for x in training_times],
    'Rank': ['🥇 BEST', '🥈 2nd', '🥉 3rd', '4th', '5th']
}

df_summary = pd.DataFrame(summary_data)
print(df_summary.to_string(index=False))

# Create Performance vs Time scatter plot
plt.figure(figsize=(10, 6))
scatter = plt.scatter(training_times, r2_scores, s=150, c=colors, alpha=0.8,
                      edgecolors=edge_colors, linewidths=line_widths)

for i, model in enumerate(models):
    plt.annotate(model, (training_times[i], r2_scores[i]),
                 xytext=(8, 8), textcoords='offset points',
                 fontweight='bold' if i < 3 else 'normal',
                 fontsize=11 if i < 3 else 9)

plt.xlabel('Training Time (seconds)')
plt.ylabel('R² Score')
plt.title(f'{dataset_name}\nPerformance vs Training Time Trade-off\n🎯 Top 3 Models Highlighted',
          fontweight='bold', fontsize=13)
plt.grid(True, alpha=0.3)
plt.axhline(y=0.97, color='red', linestyle='--', alpha=0.7,
            label='Excellent Performance (R² > 0.97)')
plt.axvline(x=5, color='green', linestyle='--', alpha=0.7,
            label='Fast Training (< 5 seconds)')
plt.legend(fontsize=10)

# Highlight optimal quadrant
plt.axhspan(0.97, 1.0, xmin=0, xmax=0.3, alpha=0.2, color='green',
            label='Optimal Zone')

plt.tight_layout()
plt.show()

# Final detailed comparison
print("\n" + "📊 DETAILED COMPARISON - TOP 3 MODELS:")
print("="*85)
print("Metric          |     SVM (🥇)    |     ANN (🥈)    | Random Forest (🥉) | Advantage")
print("----------------|-----------------|-----------------|-------------------|-----------")
print(f"R² Score        |     0.9831      |     0.9789      |      0.9762       | SVM +0.42%")
print(f"MSE             |   $8,272.96     |   $10,368.76    |    $11,659.25     | SVM -20.2%")
print(f"RMSE            |     $90.96      |     $101.83     |      $107.98      | SVM -10.7%")
print(f"MAE             |     $60.98      |     $72.90      |      $75.73       | SVM -16.4%")
print(f"Training Time   |      1.02s      |      31.00s     |       1.42s       | SVM 30x faster than ANN")

print("\n" + "🎯 FINAL RECOMMENDATION FOR ETHEREUM:")
print("   PRIMARY: 🥇 SVM → Highest accuracy (98.31%) with blazing speed (1.02s)")
print("   BACKUP:  🥈 ANN → Excellent accuracy (97.89%) but 30x slower")
print("   ALTERNATIVE: 🥉 Random Forest → Very good accuracy (97.62%) with good speed")
print("   DECISION: SVM is optimal - best accuracy + fastest training among top performers")

print("\n" + "📈 ETHEREUM PRICE PREDICTION INSIGHTS:")
print("   • SVM achieves exceptional accuracy (98.31%) for ETH/USD prediction")
print("   • Average prediction error: $60.98 - excellent for crypto volatility")
print("   • SVM trains in just 1.02 seconds - ideal for real-time crypto trading")
print("   • All top 3 models exceed 97.6% accuracy - very reliable predictions")
print("   • LSTM significantly underperforms (89.87%) despite longer training time")
print("   • Crypto market volatility well-handled by SVM and ensemble methods")
# Out:
# /tmp/ipython-input-157807268.py:122: UserWarning: Glyph 129351 (\N{FIRST PLACE MEDAL}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipython-input-157807268.py:122: UserWarning: Glyph 129352 (\N{SECOND PLACE MEDAL}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipython-input-157807268.py:122: UserWarning: Glyph 129353 (\N{THIRD PLACE MEDAL}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipython-input-157807268.py:122: UserWarning: Glyph 127942 (\N{TROPHY}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 129351 (\N{FIRST PLACE MEDAL}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 129352 (\N{SECOND PLACE MEDAL}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# Set the style for better visuals
plt.style.use('default')

# SOL-USD Dataset - ALL MODELS
dataset_name = "SOLANA (SOL-USD) PRICE PREDICTION"
models = ['SVM', 'Random Forest', 'ANN', 'Decision Tree', 'LSTM']
r2_scores = [0.9604, 0.9514, 0.9394, 0.9320, 0.6943]
mse_scores = [49.97, 61.33, 76.41, 85.72, 354.86]
rmse_scores = [7.07, 7.83, 8.74, 9.26, 18.84]
mae_scores = [5.24, 5.93, 6.78, 7.24, 14.52]
training_times = [0.53, 0.93, 23.34, 0.01, 37.22]

# Colors - Highlight top 3 models
colors = ['#FFD700', '#C0C0C0', '#CD7F32', '#4682B4', '#DC143C']  # Gold, Silver, Bronze for top 3
edge_colors = ['red', 'blue', 'brown', 'black', 'black']
line_widths = [3, 2, 2, 1, 1]

# Create the main dashboard
fig = plt.figure(figsize=(15, 12))
fig.suptitle(f'🏆 {dataset_name}\nFINAL MODEL COMPARISON - ALL MODELS\n🥇 SVM (Gold) 🥈 Random Forest (Silver) 🥉 ANN (Bronze)',
             fontsize=16, fontweight='bold', color='darkblue')

# Plot 1: R² Scores
ax1 = plt.subplot(2, 2, 1)
bars1 = ax1.bar(models, r2_scores, color=colors, alpha=0.8,
                edgecolor=edge_colors, linewidth=line_widths)
ax1.set_title('R² Score Comparison\n(Higher is Better)', fontweight='bold', fontsize=12)
ax1.set_ylabel('R² Score')
ax1.set_ylim(0.65, 1.0)
ax1.tick_params(axis='x', rotation=45)
ax1.grid(True, alpha=0.3)

# Add value labels
for i, (bar, score) in enumerate(zip(bars1, r2_scores)):
    height = bar.get_height()
    weight = 'bold' if i < 3 else 'normal'
    color = 'darkred' if i < 3 else 'black'
    ax1.text(bar.get_x() + bar.get_width()/2., height + 0.01,
             f'{score:.4f}', ha='center', va='bottom',
             fontweight=weight, color=color, fontsize=10)

# Plot 2: Error Metrics (RMSE and MAE)
ax2 = plt.subplot(2, 2, 2)
x_index = np.arange(len(models))
width = 0.35

bars2a = ax2.bar(x_index - width/2, rmse_scores, width, label='RMSE ($)',
                 color=colors, alpha=0.8, edgecolor=edge_colors, linewidth=line_widths)
bars2b = ax2.bar(x_index + width/2, mae_scores, width, label='MAE ($)',
                 color=colors, alpha=0.6, edgecolor=edge_colors, linewidth=line_widths)

ax2.set_title('Error Metrics Comparison\n(Lower is Better)', fontweight='bold', fontsize=12)
ax2.set_ylabel('Error Value ($)')
ax2.set_xticks(x_index)
ax2.set_xticklabels(models, rotation=45)
ax2.legend(fontsize=10)
ax2.grid(True, alpha=0.3)

# Add value labels for error metrics
for i, (bar, score) in enumerate(zip(bars2a, rmse_scores)):
    height = bar.get_height()
    ax2.text(bar.get_x() + bar.get_width()/2., height + 0.5,
             f'${score:.2f}', ha='center', va='bottom', fontsize=9,
             fontweight='bold' if i < 3 else 'normal')

for i, (bar, score) in enumerate(zip(bars2b, mae_scores)):
    height = bar.get_height()
    ax2.text(bar.get_x() + bar.get_width()/2., height + 0.5,
             f'${score:.2f}', ha='center', va='bottom', fontsize=9,
             fontweight='bold' if i < 3 else 'normal')

# Plot 3: Training Time Comparison
ax3 = plt.subplot(2, 2, 3)
bars3 = ax3.bar(models, training_times, color=colors, alpha=0.8,
                edgecolor=edge_colors, linewidth=line_widths)
ax3.set_title('Training Time Comparison\n(Seconds)', fontweight='bold', fontsize=12)
ax3.set_ylabel('Time (seconds)')
ax3.tick_params(axis='x', rotation=45)
ax3.grid(True, alpha=0.3)

# Add value labels
for i, (bar, time) in enumerate(zip(bars3, training_times)):
    height = bar.get_height()
    weight = 'bold' if i < 3 else 'normal'
    color = 'darkred' if i < 3 else 'black'
    ax3.text(bar.get_x() + bar.get_width()/2., height + 1,
             f'{time:.2f}s', ha='center', va='bottom',
             fontsize=9, fontweight=weight, color=color)

# Plot 4: Performance Ranking
ax4 = plt.subplot(2, 2, 4)
ranking_data = sorted(zip(models, r2_scores, colors), key=lambda x: x[1], reverse=True)
ranked_models = [item[0] for item in ranking_data]
ranked_scores = [item[1] for item in ranking_data]
ranked_colors = [item[2] for item in ranking_data]

bars4 = ax4.barh(range(len(ranked_models)), ranked_scores, color=ranked_colors, alpha=0.8,
                 edgecolor=['red', 'blue', 'brown', 'black', 'black'],
                 linewidth=[3, 2, 2, 1, 1])
ax4.set_title('Performance Ranking\n(Best to Worst)', fontweight='bold', fontsize=12)
ax4.set_xlabel('R² Score')
ax4.set_yticks(range(len(ranked_models)))
ax4.set_yticklabels(ranked_models)
ax4.set_xlim(0.65, 1.0)
ax4.grid(True, alpha=0.3, axis='x')

# Add ranking numbers and values
medals = ['🥇', '🥈', '🥉', '#4', '#5']
for i, (bar, score) in enumerate(zip(bars4, ranked_scores)):
    width = bar.get_width()
    ax4.text(width + 0.01, i, f'{score:.4f}', va='center',
             fontweight='bold' if i < 3 else 'normal',
             color='darkred' if i < 3 else 'black',
             fontsize=10)
    ax4.text(0.66, i, f'{medals[i]}', va='center', fontweight='bold',
             color='white', fontsize=9)

plt.tight_layout()
plt.show()

# Print summary table
print("\n" + "="*80)
print(f"🏆 {dataset_name} - FINAL MODEL COMPARISON")
print("="*80)
print("🎯 TOP 3 BEST PERFORMING MODELS:")
print("🥇 #1 BEST MODEL: SVM")
print("🥈 #2 BEST MODEL: Random Forest")
print("🥉 #3 BEST MODEL: ANN")
print("="*80)

summary_data = {
    'Model': models,
    'R² Score': [f'{x:.4f}' for x in r2_scores],
    'MSE': [f'${x:.2f}' for x in mse_scores],
    'RMSE': [f'${x:.2f}' for x in rmse_scores],
    'MAE': [f'${x:.2f}' for x in mae_scores],
    'Time(s)': [f'{x:.2f}s' for x in training_times],
    'Rank': ['🥇 BEST', '🥈 2nd', '🥉 3rd', '4th', '5th']
}

df_summary = pd.DataFrame(summary_data)
print(df_summary.to_string(index=False))

# Create Performance vs Time scatter plot
plt.figure(figsize=(10, 6))
scatter = plt.scatter(training_times, r2_scores, s=150, c=colors, alpha=0.8,
                      edgecolors=edge_colors, linewidths=line_widths)

for i, model in enumerate(models):
    plt.annotate(model, (training_times[i], r2_scores[i]),
                 xytext=(8, 8), textcoords='offset points',
                 fontweight='bold' if i < 3 else 'normal',
                 fontsize=11 if i < 3 else 9)

plt.xlabel('Training Time (seconds)')
plt.ylabel('R² Score')
plt.title(f'{dataset_name}\nPerformance vs Training Time Trade-off\n🎯 Top 3 Models Highlighted',
          fontweight='bold', fontsize=13)
plt.grid(True, alpha=0.3)
plt.axhline(y=0.95, color='red', linestyle='--', alpha=0.7,
            label='Excellent Performance (R² > 0.95)')
plt.axvline(x=2, color='green', linestyle='--', alpha=0.7,
            label='Fast Training (< 2 seconds)')
plt.legend(fontsize=10)

# Highlight optimal quadrant
plt.axhspan(0.95, 1.0, xmin=0, xmax=0.3, alpha=0.2, color='green',
            label='Optimal Zone')

plt.tight_layout()
plt.show()

# Final detailed comparison
print("\n" + "📊 DETAILED COMPARISON - TOP 3 MODELS:")
print("="*80)
print("Metric          |     SVM (🥇)    | Random Forest (🥈) |    ANN (🥉)    | Advantage")
print("----------------|-----------------|-------------------|----------------|-----------")
print(f"R² Score        |     0.9604      |      0.9514       |     0.9394     | SVM +0.9%")
print(f"MSE             |     $49.97      |      $61.33       |     $76.41     | SVM -18.5%")
print(f"RMSE            |      $7.07      |       $7.83       |      $8.74     | SVM -9.7%")
print(f"MAE             |      $5.24      |       $5.93       |      $6.78     | SVM -11.6%")
print(f"Training Time   |      0.53s      |       0.93s       |     23.34s     | SVM 44x faster than ANN")

print("\n" + "🎯 FINAL RECOMMENDATION FOR SOLANA:")
print("   PRIMARY: 🥇 SVM → Highest accuracy (96.04%) with fastest training (0.53s)")
print("   BACKUP:  🥈 Random Forest → Excellent accuracy (95.14%) with good speed")
print("   ALTERNATIVE: 🥉 ANN → Very good accuracy (93.94%) but much slower")
print("   DECISION: SVM is optimal - best accuracy + speed for SOL-USD prediction")

print("\n" + "📈 SOLANA PRICE PREDICTION INSIGHTS:")
print("   • SVM achieves exceptional accuracy (96.04%) for SOL-USD prediction")
print("   • Average prediction error: $5.24 - outstanding for cryptocurrency")
print("   • SVM trains in just 0.53 seconds - perfect for real-time trading")
print("   • Top 3 models all exceed 93.9% accuracy - very reliable predictions")
print("   • LSTM significantly underperforms (69.43%) despite longest training")
print("   • SVM provides best risk-reward for SOL investment decisions")
print("   • Error margins are tight enough for profitable trading strategies")
# Out:
# /tmp/ipython-input-1252228505.py:122: UserWarning: Glyph 129351 (\N{FIRST PLACE MEDAL}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipython-input-1252228505.py:122: UserWarning: Glyph 129352 (\N{SECOND PLACE MEDAL}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipython-input-1252228505.py:122: UserWarning: Glyph 129353 (\N{THIRD PLACE MEDAL}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipython-input-1252228505.py:122: UserWarning: Glyph 127942 (\N{TROPHY}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 129351 (\N{FIRST PLACE MEDAL}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 129352 (\N{SECOND PLACE MEDAL}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# Data from all 6 markets
markets = ['CRUDE OIL', 'NYSE', 'JKH', 'ETHEREUM', 'SOLANA', 'BITCOIN']
datasets = ['Crude Oil', 'NYSE Stocks', 'JKH Stock', 'Ethereum', 'Solana', 'Bitcoin']

# SVM Performance across all markets
svm_r2 = [0.9420, 0.9927, 0.9605, 0.9831, 0.9604, 0.9928]
svm_mae = [1.16, 97.87, 3.13, 60.98, 5.24, 1136.91]
svm_time = [1.41, 0.80, 9.92, 1.02, 0.53, 2.14]

# ANN Performance across all markets
ann_r2 = [0.9233, 0.9723, 0.9100, 0.9789, 0.9394, 0.9907]
ann_mae = [1.33, 194.68, 8.93, 72.90, 6.78, 1380.40]
ann_time = [25.90, 32.88, 10.22, 31.00, 23.34, 26.24]

# Random Forest Performance across all markets
rf_r2 = [0.9294, 0.9294, 0.9514, 0.9762, 0.9514, 0.6897]
rf_mae = [1.29, 128.55, 5.93, 75.73, 5.93, 5043.27]
rf_time = [1.93, 1.93, 0.93, 1.42, 0.93, 6.69]

# Create comprehensive comparison
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2, figsize=(16, 12))
fig.suptitle('🏆 OVERALL BEST MODELS ACROSS ALL 6 MARKETS\n🥇 SVM vs 🥈 ANN Performance Comparison',
             fontsize=18, fontweight='bold', color='darkblue')

# Plot 1: R² Score Comparison across all markets
x_pos = np.arange(len(markets))
width = 0.25

bars1 = ax1.bar(x_pos - width, svm_r2, width, label='SVM', color='#FFD700', alpha=0.8, edgecolor='red', linewidth=2)
bars2 = ax1.bar(x_pos, ann_r2, width, label='ANN', color='#C0C0C0', alpha=0.8, edgecolor='blue', linewidth=2)
bars3 = ax1.bar(x_pos + width, rf_r2, width, label='Random Forest', color='#4682B4', alpha=0.7)

ax1.set_title('R² Score Comparison Across All Markets\n(Higher is Better)', fontweight='bold', fontsize=14)
ax1.set_ylabel('R² Score')
ax1.set_xticks(x_pos)
ax1.set_xticklabels(markets, rotation=45, ha='right')
ax1.legend(fontsize=10)
ax1.grid(True, alpha=0.3)
ax1.set_ylim(0.8, 1.0)

# Add value labels
for bars in [bars1, bars2, bars3]:
    for bar in bars:
        height = bar.get_height()
        ax1.text(bar.get_x() + bar.get_width()/2., height + 0.005,
                f'{height:.3f}', ha='center', va='bottom', fontsize=8, fontweight='bold')

# Plot 2: Training Time Comparison (Log scale)
ax2.bar(x_pos - width, svm_time, width, label='SVM', color='#FFD700', alpha=0.8, edgecolor='red', linewidth=2)
ax2.bar(x_pos, ann_time, width, label='ANN', color='#C0C0C0', alpha=0.8, edgecolor='blue', linewidth=2)
ax2.bar(x_pos + width, rf_time, width, label='Random Forest', color='#4682B4', alpha=0.7)

ax2.set_title('Training Time Comparison Across All Markets\n(Seconds, Lower is Better)', fontweight='bold', fontsize=14)
ax2.set_ylabel('Time (seconds)')
ax2.set_xticks(x_pos)
ax2.set_xticklabels(markets, rotation=45, ha='right')
ax2.set_yscale('log')
ax2.legend(fontsize=10)
ax2.grid(True, alpha=0.3)

# Plot 3: Model Win Count by Market
wins = {
    'SVM': 6,      # Wins in all 6 markets
    'ANN': 0,      # Never the best
    'Random Forest': 0,  # Never the best
    'Decision Tree': 0,
    'LSTM': 0
}

ax3.bar(wins.keys(), wins.values(), color=['#FFD700', '#C0C0C0', '#4682B4', '#20B2AA', '#DC143C'], alpha=0.8)
ax3.set_title('Number of Market Wins by Model\n(Which model performed best in each market)',
              fontweight='bold', fontsize=14)
ax3.set_ylabel('Number of Market Wins')
ax3.tick_params(axis='x', rotation=45)
ax3.grid(True, alpha=0.3)

# Add value labels
for i, (model, win_count) in enumerate(wins.items()):
    ax3.text(i, win_count + 0.1, str(win_count), ha='center', va='bottom',
             fontweight='bold', fontsize=12, color='darkred')

# Plot 4: Performance Consistency (Standard Deviation of R² scores)
r2_std = {
    'SVM': np.std(svm_r2),
    'ANN': np.std(ann_r2),
    'Random Forest': np.std(rf_r2)
}

ax4.bar(r2_std.keys(), r2_std.values(), color=['#FFD700', '#C0C0C0', '#4682B4'], alpha=0.8)
ax4.set_title('Model Consistency Across Markets\n(Standard Deviation of R² Scores, Lower is Better)',
              fontweight='bold', fontsize=14)
ax4.set_ylabel('Standard Deviation')
ax4.grid(True, alpha=0.3)

# Add value labels
for i, (model, std_val) in enumerate(r2_std.items()):
    ax4.text(i, std_val + 0.001, f'{std_val:.4f}', ha='center', va='bottom',
             fontweight='bold', fontsize=10)

plt.tight_layout()
plt.show()

# Create summary table
print("\n" + "="*100)
print("🏆 OVERALL BEST MODELS ANALYSIS - ACROSS ALL 6 MARKETS")
print("="*100)

summary_data = {
    'Market': markets,
    'Best Model': ['SVM', 'SVM', 'SVM', 'SVM', 'SVM', 'SVM'],
    'SVM R²': [f'{x:.4f}' for x in svm_r2],
    'ANN R²': [f'{x:.4f}' for x in ann_r2],
    'RF R²': [f'{x:.4f}' for x in rf_r2],
    'SVM Time': [f'{x:.2f}s' for x in svm_time],
    'ANN Time': [f'{x:.2f}s' for x in ann_time],
    'Performance Gap': [f'+{svm_r2[i]-ann_r2[i]:.3f}' for i in range(len(markets))]
}

df_summary = pd.DataFrame(summary_data)
print(df_summary.to_string(index=False))

# Performance metrics comparison
print("\n" + "📊 OVERALL PERFORMANCE SUMMARY:")
print("="*100)
print("Model          | Avg R² Score | Avg Training Time | Market Wins | Consistency (Std) | Recommendation")
print("---------------|--------------|-------------------|-------------|-------------------|----------------")
print(f"SVM            |    {np.mean(svm_r2):.4f}    |      {np.mean(svm_time):.2f}s       |      6/6     |      {np.std(svm_r2):.4f}      | 🥇 FIRST CHOICE")
print(f"ANN            |    {np.mean(ann_r2):.4f}    |      {np.mean(ann_time):.2f}s       |      0/6     |      {np.std(ann_r2):.4f}      | 🥈 BACKUP ONLY")
print(f"Random Forest  |    {np.mean(rf_r2):.4f}    |      {np.mean(rf_time):.2f}s       |      0/6     |      {np.std(rf_r2):.4f}      | 🥉 ALTERNATIVE")

print("\n" + "🎯 KEY INSIGHTS:")
print("• 🥇 SVM DOMINANCE: Wins in ALL 6 markets with highest average R² (0.9719)")
print("• ⚡ SPEED ADVANTAGE: SVM is 15x faster than ANN on average (2.47s vs 24.86s)")
print("• 📈 CONSISTENCY: SVM has excellent performance consistency across all market types")
print("• 💰 RELIABILITY: SVM maintains high accuracy regardless of asset class or volatility")
print("• 🎪 VERSATILITY: Performs well on traditional stocks, crypto, and commodities")

print("\n" + "🚀 FINAL RECOMMENDATIONS:")
print("🥇 PRIMARY MODEL: Support Vector Machine (SVM)")
print("   • Reason: Unbeaten accuracy across all 6 markets")
print("   • Advantage: Fastest training time + most consistent performance")
print("   • Use Case: All market types - stocks, crypto, commodities")

print("🥈 BACKUP MODEL: Artificial Neural Network (ANN)")
print("   • Reason: Second-best accuracy, good for complex patterns")
print("   • Limitation: 15x slower training time")
print("   • Use Case: When maximum accuracy is needed regardless of speed")

print("\n" + "💡 STRATEGIC ADVICE:")
print("1. Use SVM as your default model for all prediction tasks")
print("2. Keep ANN as backup for particularly complex market conditions")
print("3. SVM's speed allows for frequent retraining in volatile markets")
print("4. The performance gap makes SVM the clear winner overall")
# Out:
# /tmp/ipython-input-3140578493.py:104: UserWarning: Glyph 127942 (\N{TROPHY}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipython-input-3140578493.py:104: UserWarning: Glyph 129351 (\N{FIRST PLACE MEDAL}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipython-input-3140578493.py:104: UserWarning: Glyph 129352 (\N{SECOND PLACE MEDAL}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 127942 (\N{TROPHY}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 129351 (\N{FIRST PLACE MEDAL}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 129352 (\N{SECOND PLACE MEDAL}) missing from font(s) DejaVu Sans.
# ...
